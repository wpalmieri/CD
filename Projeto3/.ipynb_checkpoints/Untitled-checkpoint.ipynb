# %% [markdown]
# # Projeto 3

# %% [markdown]
# ### Gabriel Noal & William Palmieri

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
notas1 = pd.read_excel("Agriculture (p of GDP).xlsx")
notas1
# Out:
#                           País  Agriculture, value added (% of GDP)
# 0                     Abkhazia                                  NaN
# 1                  Afghanistan                            31.177550
# 2        Akrotiri and Dhekelia                                  NaN
# 3                      Albania                            20.401935
# 4                      Algeria                             6.915571
# 5               American Samoa                                  NaN
# 6                      Andorra                                  NaN
# 7                       Angola                            10.202085
# 8                     Anguilla                                  NaN
# 9          Antigua and Barbuda                             1.771181
# 10                   Argentina                             7.503740
# 11                     Armenia                            18.913892
# 12                       Aruba                                  NaN
# ...

# %%
notas2 = pd.read_excel("indicator gapminder infant_mortality.xlsx")
notas2
# Out:
#                          País  Infant mortality rate
# 0                    Abkhazia                    NaN
# 1                 Afghanistan                   76.8
# 2       Akrotiri and Dhekelia                    NaN
# 3                     Albania                   15.4
# 4                     Algeria                   24.3
# 5              American Samoa                    NaN
# 6                     Andorra                    2.6
# 7                      Angola                  112.2
# 8                    Anguilla                    NaN
# 9         Antigua and Barbuda                    8.2
# 10                  Argentina                   13.4
# 11                    Armenia                   17.0
# 12                      Aruba                    NaN
# 13                  Australia                    4.2
# 14                    Austria                    3.7
# 15                 Azerbaijan                   35.5
# 16                    Bahamas                   11.7
# ...

# %%
notas3 = pd.read_excel("indicator ti cpi 2009.xlsx")
notas3
# Out:
#                        Países  CPI
# 0                 New Zealand  9.3
# 1                     Denmark  9.3
# 2                      Sweden  9.2
# 3                   Singapore  9.3
# 4                 Switzerland  8.7
# 5                     Finland  9.2
# 6                 Netherlands  8.8
# 7                     Iceland  8.5
# 8                      Canada  8.9
# 9                   Australia  8.7
# 10                     Norway  8.6
# 11                 Luxembourg  8.5
# 12           Hong Kong, China  8.4
# 13                    Ireland  8.0
# 14                    Germany  7.9
# 15                    Austria  7.9
# 16             United Kingdom  7.6
# 17                      Japan  7.8
# 18              United States  7.1
# 19                   Barbados  7.8
# 20                    Belgium  7.1
# 21                Saint Lucia  NaN
# 22                      Qatar  7.7
# 23                     France  6.8
# 24                    Uruguay  6.9
# 25                      Chile  7.2
# ...

# %%
notas4 = pd.read_excel("Indicator_HDI.xlsx")
notas4
# Out:
#                         Países    HDI
# 0                     Abkhazia    NaN
# 1                  Afghanistan  0.387
# 2        Akrotiri and Dhekelia    NaN
# 3                      Albania  0.734
# 4                      Algeria  0.691
# 5               American Samoa    NaN
# 6                      Andorra    NaN
# 7                       Angola  0.481
# 8                     Anguilla    NaN
# 9          Antigua and Barbuda    NaN
# 10                   Argentina  0.788
# 11                     Armenia  0.712
# 12                       Aruba    NaN
# 13                   Australia  0.926
# 14                     Austria  0.879
# 15                  Azerbaijan    NaN
# 16                     Bahamas  0.769
# 17                     Bahrain  0.805
# 18                  Bangladesh  0.491
# 19                    Barbados  0.790
# 20                     Belarus  0.746
# 21                     Belgium  0.883
# 22                      Belize  0.696
# 23                       Benin  0.422
# ...

# %%
notas5 = pd.read_excel("Service (p of GDP).xlsx")
notas5
# Out:
#                        Países  Services, etc., value added (% of GDP)
# 0                 Afghanistan                               47.607657
# 1                     Albania                               60.239255
# 2                     Algeria                               30.960967
# 3              American Samoa                                     NaN
# 4                     Andorra                                     NaN
# 5                      Angola                               30.751248
# 6         Antigua and Barbuda                               76.285758
# 7                   Argentina                               60.697484
# 8                     Armenia                               45.280450
# 9                       Aruba                                     NaN
# 10                  Australia                               76.374114
# 11                    Austria                               69.354040
# ...
