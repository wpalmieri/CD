# %%
# %matplotlib inline
from scipy.stats import t
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
fig, ax = plt.subplots(1, 1)
df = 30
#mean, var, skew, kurt = t.stats(df, moments='mvsk')
x = np.linspace(t.ppf(0.01, df), t.ppf(0.99, df), 100)
ax.plot(x, t.pdf(x, df))
plt.plot(x,norm.pdf(x,loc=0,scale=1))
plt.show()

# %%
w = t.pdf(x, df)
print (w)
print ('Desv. pad', np.std(w))
var = np.std(w)**2
print ('Variância:', var)
phi = 
print ('Grau de liberdade:', )
# Out:
# [ 0.02305979  0.02559276  0.02836301  0.03138673  0.03468041  0.0382606
#   0.04214387  0.04634654  0.05088458  0.05577329  0.06102717  0.0666596
#   0.07268257  0.07910644  0.08593958  0.0931881   0.10085555  0.10894254
#   0.1174465   0.12636134  0.13567721  0.14538017  0.15545204  0.16587017
#   0.17660729  0.18763145  0.19890595  0.2103894   0.22203579  0.23379469
#   0.24561149  0.25742772  0.26918145  0.2808078   0.29223946  0.30340732
#   0.31424116  0.32467039  0.3346248   0.34403537  0.35283512  0.36095989
#   0.36834919  0.37494698  0.38070237  0.38557037  0.38951247  0.39249719
#   0.39450053  0.39550627  0.39550627  0.39450053  0.39249719  0.38951247
#   0.38557037  0.38070237  0.37494698  0.36834919  0.36095989  0.35283512
#   0.34403537  0.3346248   0.32467039  0.31424116  0.30340732  0.29223946
#   0.2808078   0.26918145  0.25742772  0.24561149  0.23379469  0.22203579
#   0.2103894   0.19890595  0.18763145  0.17660729  0.16587017  0.15545204
#   0.14538017  0.13567721  0.12636134  0.1174465   0.10894254  0.10085555
#   0.0931881   0.08593958  0.07910644  0.07268257  0.0666596   0.06102717
#   0.05577329  0.05088458  0.04634654  0.04214387  0.0382606   0.03468041
#   0.03138673  0.02836301  0.02559276  0.02305979]
# Desv. pad 0.128645372665
# Variância: 0.016549631908
# Grau de liberdade
