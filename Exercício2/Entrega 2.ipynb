# %% [markdown]
# # Entrega 2

# %% [markdown]
# ## <font color='blue'>William Palmieri</font>
# ___

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
notas = pd.read_table("pes2013A.txt", encoding = "windows-1252", sep=" ")

# %%
tab["Região"] = notas.UF



notas.Região[(notas.UF == 11 )| (notas.UF == 12 )| (notas.UF == 13 )| (notas.UF == 14 )| (notas.UF == 15 )| (notas.UF == 16 )| (notas.UF == 17)] = "Norte"
notas.Região[(notas.UF == 21 )| (notas.UF == 22 )| (notas.UF == 23 )| (notas.UF == 24 )| (notas.UF == 25 )| (notas.UF == 26 )| (notas.UF == 27 )| (notas.UF == 28 )| (notas.UF == 29)] = "Nordeste"
notas.Região[(notas.UF == 31 )| (notas.UF == 32 )| (notas.UF == 33 )| (notas.UF == 35)] = "Sudeste"
notas.Região[(notas.UF == 41 )| (notas.UF == 42 )| (notas.UF == 43)] = "Sul"
notas.Região[(notas.UF == 50 )| (notas.UF == 51 )| (notas.UF == 52 )| (notas.UF == 53)] = "Centro-Oeste"
# Out:
# C:\Users\1234\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\1234\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\1234\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\1234\Anaconda3\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# ...

# %%
notas.V4802 = notas.V4802.astype('category')
notas.V4802.cat.categories=('maternal','Alfabetização', 'Alfabetização Adultos', 'Fund 1 JA', 'Fund 2 JA', 'Ensino Fundamental', 'Fund 1', 'Fund 2', 'EJA Modular', 'EM + Cursinho', 'Superior')

notas.V6002 = notas.V6002.astype('category')
notas.V6002.cat.categories= ('Público', 'Privado')

notas.UF = notas.UF.astype('category')
notas.UF.cat.categories=('RR', 'AC', 'AM', 'RO', 'PA', 'AP', 'TO', 'MA', 'PI', 'CE', 'RN', 'PB', 'PE', 'AL', 'SE', 'BA', 'MG', 'ES', 'RJ', 'SP', 'PR', 'SC', 'RS', 'MS', 'MT', 'GO', 'DF')

notas.V0302 = notas.V0302.astype('category')
notas.V0302.cat.categories= ('Masculino', 'Feminino')

notas.V0404 = notas.V0404.astype('category')
notas.V0404.cat.categories= ('Branca', 'Preta', 'Amarela', 'Parda', 'Indígena', 'Sem Declaração')

notas.V4803 = notas.V4803.astype('category')
notas.V4803.cat.categories=('sem instrução', '1 anos','2 anos','3 anos','4 anos','5 anos','6 anos','7 anos','8 anos','9 anos','10 anos','11 anos','12 anos','13 anos','14 anos','15 anos +', 'nao det',)

notas.V06111 = notas.V06111.astype('category')
notas.V06111.cat.categories= ('Tem acesso a internet', 'Não tem acesso')



uf = notas.UF

#Criando DataFrame
tab = pd.DataFrame()

tab["Estado"] = notas.UF
tab["Região"] = notas.Região
tab["Idade"] = notas.V8005
tab["Renda"] = notas.V4720

#rendatotal = escolhas[(escolhas.Rend != 999999999999)].Rend

# %% [markdown]
# Tabela das variáveis que serão usadas nessa análise

# %%
tab
# Out:
#        Estado        Região  Idade  Renda
# 1          RR         Norte     42    350
# 2          RR         Norte     64    678
# 3          RR         Norte     13      0
# 4          RR         Norte     23    800
# 5          RR         Norte     19      0
# 6          RR         Norte     17      0
# 7          RR         Norte     59    800
# 8          RR         Norte     56      0
# 9          RR         Norte     25   1100
# 10         RR         Norte     23    134
# 11         RR         Norte      5    NaN
# 12         RR         Norte     37   4000
# 13         RR         Norte     25      0
# 14         RR         Norte      4    NaN
# 15         RR         Norte     50   3500
# 16         RR         Norte     23      0
# 17         RR         Norte     28   1300
# 18         RR         Norte     41   1400
# 19         RR         Norte     34      0
# 20         RR         Norte     17      0
# 21         RR         Norte     15      0
# ...

# %% [markdown]
# Primeiramente faremos uma análise geral das variáveis quantitativas escolhidas: "Idade" e "Renda Média".

# %%
faixa = np.arange(0,120,10)
faixa2 = np.arange(0,6000,200)

#Renda média de uma família do Pais
tab.Renda.describe()

#Plotando a RM
tab.Renda.plot.hist(bins=faixa2, normed=1, color="salmon", figsize = (8, 8))
plt.title("Histograma de Renda Média do Pais")
plt.xlabel("Renda Mensal (reais)")
plt.ylabel("Frequência relativa")

# %%
#Idade da População
tab.Idade.describe()

#Plotando Idade
tab.Idade.plot.hist(bins=faixa, normed=1, color="darkcyan", figsize = (8, 8))
plt.title("Histograma de Idade")
plt.xlabel("Idade (Anos)")
plt.ylabel("Frequência relativa")

# %%
tab.boxplot(column="Idade", by="Região", figsize = (10, 10))
plt.show()

# %% [markdown]
# Como isso não mostra muitas informações, serão feitas tabelas para cada uma das regiões.

# %%
#Reda da Região Nordeste
rendaNordeste = tab[(tab.Região == "Nordeste")].Renda

#Plotando o gráfico
rendaNordeste.plot.hist(bins=faixa2, normed=1, color="salmon", figsize = (8,8))
plt.title("Renda Média na Região Nordeste")
plt.xlabel("Renda (Reais)")
plt.ylabel("Frequência relativa")
plt.show()



#Idade da Região Nordeste
idNordeste = tab[(tab.Região == "Nordeste")].Idade

#Plotando o gráfico
idNordeste.plot.hist(bins=faixa, normed=1, color="darkcyan", figsize = (8,8))
plt.title("Idade Região Nordeste")
plt.xlabel("Idade (Anos)")
plt.ylabel("Frequência relativa")
plt.show()

# %%
#Reda da Região Nordeste
rendaNorte = tab[(tab.Região == "Norte")].Renda

#Plotando o gráfico
rendaNorte.plot.hist(bins=faixa2, normed=1, color="salmon", figsize = (8,8))
plt.title("Renda Média na Região Norte")
plt.xlabel("Renda (Reais)")
plt.ylabel("Frequência relativa")
plt.show()



#Idade da Região Nordeste
idNorte = tab[(tab.Região == "Norte")].Idade

#Plotando o gráfico
idNorte.plot.hist(bins=faixa, normed=1, color="darkcyan", figsize = (8,8))
plt.title("Idade Região Norte")
plt.xlabel("Idade (Anos)")
plt.ylabel("Frequência relativa")
plt.show()

# %%
#Reda da Região Sudeste
rendaSudeste = tab[(tab.Região == "Sudeste")].Renda

#Plotando o gráfico
rendaSudeste.plot.hist(bins=faixa2, normed=1, color="salmon", figsize = (8,8))
plt.title("Renda Média na Região Sudeste")
plt.xlabel("Renda (Reais)")
plt.ylabel("Frequência relativa")
plt.show()



#Idade da Região Sudeste
idSudeste = tab[(tab.Região == "Sudeste")].Idade

#Plotando o gráfico
idSudeste.plot.hist(bins=faixa, normed=1, color="darkcyan", figsize = (8,8))
plt.title("Idade Região Sudeste")
plt.xlabel("Idade (Anos)")
plt.ylabel("Frequência relativa")
plt.show()

# %%
#Reda da Região Sul
rendaSul = tab[(tab.Região == "Sul")].Renda

#Plotando o gráfico
rendaSul.plot.hist(bins=faixa2, normed=1, color="salmon", figsize = (8,8))
plt.title("Renda Média na Região Sul")
plt.xlabel("Renda (Reais)")
plt.ylabel("Frequência relativa")
plt.show()



#Idade da Região Sul
idSul = tab[(tab.Região == "Sul")].Idade

#Plotando o gráfico
idSul.plot.hist(bins=faixa, normed=1, color="darkcyan", figsize = (8,8))
plt.title("Idade Região Sull")
plt.xlabel("Idade (Anos)")
plt.ylabel("Frequência relativa")
plt.show()

# %%
#Reda da Região Centro-Oeste
rendaCO = tab[(tab.Região == "Centro-Oeste")].Renda

#Plotando o gráfico
rendaCO.plot.hist(bins=faixa2, normed=1, color="salmon", figsize = (8,8))
plt.title("Renda Média na Região Centro-Oeste")
plt.xlabel("Renda (Reais)")
plt.ylabel("Frequência relativa")
plt.show()



#Idade da Região CentroOeste
idCO = tab[(tab.Região == "Centro-Oeste")].Idade

#Plotando o gráfico
idCO.plot.hist(bins=faixa, normed=1, color="darkcyan", figsize = (8,8))
plt.title("Idade Região Centro-Oeste")
plt.xlabel("Idade (Anos)")
plt.ylabel("Frequência relativa")
plt.show()

# %%
#Reda da Região Centro-Oeste
rendaCO = tab[(tab.Região == "Centro-Oeste")].Renda

#Plotando o gráfico
rendaCO.plot.hist(bins=faixa2, normed=1, color="salmon", figsize = (8,8))
plt.title("Renda Média na Região Centro-Oeste")
plt.xlabel("Renda (Reais)")
plt.ylabel("Frequência relativa")
plt.show()



#Idade da Região CentroOeste
idCO = tab[(tab.Região == "Centro-Oeste")].Idade

#Plotando o gráfico
idCO.plot.hist(bins=faixa, normed=1, color="darkcyan", figsize = (8,8))
plt.title("Idade Região Centro-Oeste")
plt.xlabel("Idade (Anos)")
plt.ylabel("Frequência relativa")
plt.show()

# %% [markdown]
# Baseado nos gráficos feitos e nos resultados obtidos ao analisar as variáveis Qualitativas, a região escolhida para uma análise mais precisa foi a região nordeste.
# Como já era sabido da análise qualitativa que os estados "Ceará" e "Bahia" eram potenciais, será feita uma análise mais precisa desses.

# %%
tab2 = pd.DataFrame()

tab2["Estado"] = notas.UF
tab2["Região1"] = notas.Região
tab2["Idade"] = notas.V8005
tab2["Renda1"] = notas.V4720

# %%
#Renda do Ceará
rendaECE = tab[(tab.Estado == "CE")].Renda

#Plotando o gráfico
rendaECE.plot.hist(bins=faixa2, normed=1, color="salmon", figsize = (8,8))
plt.title("Renda Média do Ceará")
plt.xlabel("Renda (Reais)")
plt.ylabel("Frequência relativa")
plt.show()



#Idade do Ceará
idECE = tab[(tab.Estado == "CE")].Idade

#Plotando o gráfico
idECE.plot.hist(bins=faixa, normed=1, color="darkcyan", figsize = (8,8))
plt.title("Faixa de Idade do Ceará")
plt.xlabel("Idade (Anos)")
plt.ylabel("Frequência relativa")
plt.show()

tabcut = tab2.iloc[80000:90000, :]
#tabcut

tabcut.boxplot(column="Idade", by = "Estado", figsize = (10,10))
plt.show()

# %%
#Renda da Bahia
rendaEBA = tab[(tab.Estado == "BA")].Renda

#Plotando o gráfico
rendaEBA.plot.hist(bins=faixa2, normed=1, color="salmon", figsize = (8,8))
plt.title("Renda Média da Bahia")
plt.xlabel("Renda (Reais)")
plt.ylabel("Frequência relativa")
plt.show()



#Idade da Bahia
idEBA = tab[(tab.Estado == "BA")].Idade

#Plotando o gráfico
idEBA.plot.hist(bins=faixa, normed=1, color="darkcyan", figsize = (8,8))
plt.title("Faixa de Idade do Bahia")
plt.xlabel("Idade (Anos)")
plt.ylabel("Frequência relativa")
plt.show()

tabcut2 = tab2.iloc[138000:150000, :]
#tabcut

tabcut2.boxplot(column="Idade", by = "Estado", figsize = (10,10))
plt.show()

# %% [markdown]
# Além dos dados anteriores, podemos ver que se analisarmos a renda por família e a faixa etária mais propensa a estudo, podemos continuar na nossa hipótese anterior de que, o sudeste tem mais renda e população, mas a região nordeste têm um mercado promissor, especialmente o Ceará, ainda mais pela baixa concorrência.
# Assim, a indicação seria para que o Sr. Gold abrisse sua faculdade no Ceará.
